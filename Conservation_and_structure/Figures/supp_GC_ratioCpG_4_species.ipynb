# %%
### Data and functions

def calculate_gc_content(dna_sequence):
    dna_sequence = dna_sequence.upper()

    g_count = dna_sequence.count('G')
    c_count = dna_sequence.count('C')

    total_length = len(dna_sequence)

    if total_length == 0:
        return 0.0
    gc_content_percentage = ((g_count + c_count) / total_length) * 100

    return gc_content_percentage

def calculate_obs_exp_cpg(seq):
    num_c = seq.count('C')
    num_g = seq.count('G')

    # Count observed 'CG' dinucleotides
    obs_cpg = 0
    for i in range(len(seq) - 1):
        if seq[i:i+2] == 'CG':
            obs_cpg += 1
    
    # Calculate expected CpG
    # (avoid dividing by zero if length is 0)
    length = len(seq)
    if length == 0:
        return 0
    
    exp_cpg = (num_c * num_g) / length if length > 0 else 0
    
    # Compute O/E ratio
    oe_ratio = obs_cpg / exp_cpg if exp_cpg != 0 else 0
    return oe_ratio

ee_h=[]
ee_h_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/hsap/hg38_ee_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_h.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        ee_h_isl.append(isl_content)
neg_h=[]
neg_h_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/hsap/hg38_neg_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        neg_h.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        neg_h_isl.append(isl_content)
pos_h=[]
pos_h_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/hsap/hg38_pos_dna_seqs.tsv") as file:
    for line in file:  
        try:
            dna_sequence = line.strip().split("\t")[1]
        except IndexError:
            continue
        gc_content = calculate_gc_content(dna_sequence)
        pos_h.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        pos_h_isl.append(isl_content)

ee_m=[]
ee_m_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/mmus/mm39_ee_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_m.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        ee_m_isl.append(isl_content)
neg_m=[]
neg_m_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/mmus/mm39_neg_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        neg_m.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        neg_m_isl.append(isl_content)
pos_m=[]
pos_m_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/mmus/mm39_pos_dna_seqs.tsv") as file:
    for line in file:  
        try:
            dna_sequence = line.strip().split("\t")[1]
        except IndexError:
            continue
        gc_content = calculate_gc_content(dna_sequence)
        pos_m.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        pos_m_isl.append(isl_content)

ee_d=[]
ee_d_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/dmel/dm6_ee_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_d.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        ee_d_isl.append(isl_content)
neg_d=[]
neg_d_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/dmel/dm6_neg_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        neg_d.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        neg_d_isl.append(isl_content)
pos_d=[]
pos_d_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/dmel/dm6_pos_dna_seqs.tsv") as file:
    for line in file:  
        try:
            dna_sequence = line.strip().split("\t")[1]
        except IndexError:
            continue
        gc_content = calculate_gc_content(dna_sequence)
        pos_d.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        pos_d_isl.append(isl_content)

ee_t=[]
ee_t_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/thal/tair10_ee_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_t.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        ee_t_isl.append(isl_content)
neg_t=[]
neg_t_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/thal/tair10_neg_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        neg_t.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        neg_t_isl.append(isl_content)
pos_t=[]
pos_t_isl=[]
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/thal/tair10_pos_dna_seqs.tsv") as file:
    for line in file:  
        try:
            dna_sequence = line.strip().split("\t")[1]
        except IndexError:
            continue
        gc_content = calculate_gc_content(dna_sequence)
        pos_t.append(gc_content)
        isl_content = calculate_obs_exp_cpg(dna_sequence)
        pos_t_isl.append(isl_content)

# %%
### Data for plot
import pandas as pd

data = [
{"Species":"H.sap","Dataset":"Ctrl-","GC%":neg_h},
{"Species":"H.sap","Dataset":"EE","GC%":ee_h},
{"Species":"H.sap","Dataset":"Ctrl+","GC%":pos_h},

{"Species":"M.mus","Dataset":"Ctrl-","GC%":neg_m},
{"Species":"M.mus","Dataset":"EE","GC%":ee_m},
{"Species":"M.mus","Dataset":"Ctrl+","GC%":pos_m},

{"Species":"D.mel","Dataset":"Ctrl-","GC%":neg_d},
{"Species":"D.mel","Dataset":"EE","GC%":ee_d},
{"Species":"D.mel","Dataset":"Ctrl+","GC%":pos_d},

{"Species":"A.tha","Dataset":"Ctrl-","GC%":neg_t},
{"Species":"A.tha","Dataset":"EE","GC%":ee_t},
{"Species":"A.tha","Dataset":"Ctrl+","GC%":pos_t},
]
df_gc = pd.DataFrame(data)
df_gc_exploded = df_gc.explode('GC%') # Explode 'Nb of exons' lists into separate rows
df_gc_exploded['GC%'] = pd.to_numeric(df_gc_exploded['GC%']) # Convert 'Nb of exons' to numeric

data = [
{"Species":"H.sap","Dataset":"Ctrl-","Obs/Exp CpG":neg_h_isl},
{"Species":"H.sap","Dataset":"EE","Obs/Exp CpG":ee_h_isl},
{"Species":"H.sap","Dataset":"Ctrl+","Obs/Exp CpG":pos_h_isl},

{"Species":"M.mus","Dataset":"Ctrl-","Obs/Exp CpG":neg_m_isl},
{"Species":"M.mus","Dataset":"EE","Obs/Exp CpG":ee_m_isl},
{"Species":"M.mus","Dataset":"Ctrl+","Obs/Exp CpG":pos_m_isl},

{"Species":"D.mel","Dataset":"Ctrl-","Obs/Exp CpG":neg_d_isl},
{"Species":"D.mel","Dataset":"EE","Obs/Exp CpG":ee_d_isl},
{"Species":"D.mel","Dataset":"Ctrl+","Obs/Exp CpG":pos_d_isl},

{"Species":"A.tha","Dataset":"Ctrl-","Obs/Exp CpG":neg_t_isl},
{"Species":"A.tha","Dataset":"EE","Obs/Exp CpG":ee_t_isl},
{"Species":"A.tha","Dataset":"Ctrl+","Obs/Exp CpG":pos_t_isl},
]
df_isl = pd.DataFrame(data)
df_isl_exploded = df_isl.explode('Obs/Exp CpG') # Explode 'Nb of exons' lists into separate rows
df_isl_exploded['Obs/Exp CpG'] = pd.to_numeric(df_isl_exploded['Obs/Exp CpG']) # Convert 'Nb of exons' to numeric

# %%
### filter cpg ratio data
# Calculate IQR boundaries
Q1 = df_isl_exploded['Obs/Exp CpG'].quantile(0.25)
Q3 = df_isl_exploded['Obs/Exp CpG'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter the dataset to remove outliers
df_isl_filtered = df_isl_exploded[
    (df_isl_exploded['Obs/Exp CpG'] >= lower_bound) &
    (df_isl_exploded['Obs/Exp CpG'] <= upper_bound)
]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
from statannot import add_stat_annotation

box_pairs = [
    (("H.sap", "Ctrl-"), ("H.sap", "EE")),
    (("H.sap", "Ctrl+"), ("H.sap", "EE")),
    (("M.mus", "Ctrl-"), ("M.mus", "EE")),
    (("M.mus", "Ctrl+"), ("M.mus", "EE")),
    (("D.mel", "Ctrl-"), ("D.mel", "EE")),
    (("D.mel", "Ctrl+"), ("D.mel", "EE")),
    (("A.tha", "Ctrl-"), ("A.tha", "EE")),
    (("A.tha", "Ctrl+"), ("A.tha", "EE"))
]

##GC
fig, axes = plt.subplots(1, 2, figsize=(10, 5), sharey=False)  # 1 row, 2 columns
ax1 = sns.violinplot(data=df_gc_exploded, x="Species", y="GC%", hue="Dataset", linewidth=1, cut=0, ax=axes[0])

add_stat_annotation(ax1, data=df_gc_exploded, x="Species", y="GC%", hue="Dataset",
                    box_pairs=box_pairs,
                    test='t-test_ind', text_format='simple', loc='inside', verbose=1)

##CpG
ax2 = sns.violinplot(data=df_isl_filtered, x="Species", y='Obs/Exp CpG', hue="Dataset", linewidth=1, ax=axes[1], bw=0.5, cut=0) #cut=0,

add_stat_annotation(ax2, data=df_isl_filtered, x="Species", y='Obs/Exp CpG', hue="Dataset",
                    box_pairs=box_pairs,
                    test='t-test_ind', text_format='simple', loc='inside', verbose=1)

ax2.yaxis.set_label_position("right")
ax2.yaxis.tick_right()

ax1.set_xlabel(None)
ax2.set_xlabel(None)

## Legend
ax1.get_legend().remove()
ax2.get_legend().remove()

from matplotlib.patches import Patch

c1 = Patch(facecolor=sns.color_palette()[1], label="cEEs")
c2 = Patch(facecolor=sns.color_palette()[0], label="Ctrl-")
c3 = Patch(facecolor=sns.color_palette()[2], label="Ctrl+")

fig.legend(
    handles=[c2, c1, c3],
    loc='lower center', bbox_to_anchor=(0.5, -0.04),
    ncol=3,
    fontsize=10, frameon=False
)

## 
plt.tight_layout()

plt.savefig("/home/mouren/Images/supplementary_figures/supp_fig2/GC_CpG_all_species.pdf", format="pdf", bbox_inches="tight", dpi=450)
plt.savefig("/home/mouren/Images/supplementary_figures/supp_fig2/GC_CpG_all_species.png", format="png", bbox_inches="tight", dpi=450)
plt.show()
# Out:
# M.mus_EE v.s. M.mus_Ctrl+: t-test independent samples with Bonferroni correction, P_val=0.000e+00 stat=1.267e+02
# D.mel_Ctrl- v.s. D.mel_EE: t-test independent samples with Bonferroni correction, P_val=0.000e+00 stat=-4.030e+01
# D.mel_EE v.s. D.mel_Ctrl+: t-test independent samples with Bonferroni correction, P_val=0.000e+00 stat=2.946e+02
# A.tha_Ctrl- v.s. A.tha_EE: t-test independent samples with Bonferroni correction, P_val=0.000e+00 stat=-4.124e+01
# A.tha_EE v.s. A.tha_Ctrl+: t-test independent samples with Bonferroni correction, P_val=0.000e+00 stat=1.357e+02
# H.sap_Ctrl- v.s. H.sap_EE: t-test independent samples with Bonferroni correction, P_val=0.000e+00 stat=-1.047e+02
# H.sap_EE v.s. H.sap_Ctrl+: t-test independent samples with Bonferroni correction, P_val=0.000e+00 stat=1.344e+02
# M.mus_Ctrl- v.s. M.mus_EE: t-test independent samples with Bonferroni correction, P_val=0.000e+00 stat=-1.390e+02
# ...

# %%
#treat the dm6_gene_unprot_id files first 
awk -F'\t' 'BEGIN { OFS="\t" }
{
  for (i=1; i<=6; i++) {  #change 6 by the number of columns presents 
    if ($i == "") {
      $i = "NA"
    }
  }
  print
}' dm6_gene_unprot_id.tsv > aaa

# %%
# prioritize the uniprot/swissprot entry; then uniprot/trembl; then gene name 

## DM
dm_gene_dic = {}
with open("/mnt/project/exonhancer/ZENODO_REPO/EE_selection/other_species/data/gencode/dm6/raw/dm6_transcrit_genes_protein_coding") as file:
    for line in file:   
        dm_gene_dic[line.strip().split("\t")[0]] = line.strip().split("\t")[1]

dm_ee_id = {}
with open("/home/mouren/Data/final_files_tokeep/other_species/dm6_EE.bed") as file1:
    for line1 in file1: 
        exon = line1.strip().split("\t")[3]
        tr = (line1.strip().split("\t")[3]).split("_")[0]
        gene = dm_gene_dic[(line1.strip().split("\t")[3]).split("_")[0]]

        with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/dm6_gene_unprot_id.tsv") as file2:
            found = False
            for line2 in file2:   
                if tr == line2.strip().split("\t")[1]:
                    if line2.strip().split("\t")[3] != "NA":
                        dm_ee_id[exon] = line2.strip().split("\t")[3]
                        found = True
                    elif line2.strip().split("\t")[4] != "NA":
                        dm_ee_id[exon] = line2.strip().split("\t")[4]
                        found = True 
                    elif line2.strip().split("\t")[5] != "NA":
                        dm_ee_id[exon] = line2.strip().split("\t")[5]
                        found = True
                    elif line2.strip().split("\t")[2] != "NA":
                        dm_ee_id[exon] = line2.strip().split("\t")[2]
                        found = True                  
                    break
            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if gene == line2.strip().split("\t")[0]:
                        if line2.strip().split("\t")[3] != "NA":
                            dm_ee_id[exon] = line2.strip().split("\t")[3]
                            found = True
                        elif line2.strip().split("\t")[4] != "NA":
                            dm_ee_id[exon] = line2.strip().split("\t")[4]
                            found = True 
                        elif line2.strip().split("\t")[5] != "NA":
                            dm_ee_id[exon] = line2.strip().split("\t")[5]
                            found = True
                        elif line2.strip().split("\t")[2] != "NA":
                            dm_ee_id[exon] = line2.strip().split("\t")[2]
                            found = True                  
                        break
            if found == False:
                print(exon,tr,gene)
                dm_ee_id[exon] = "NA"

dm_neg_id = {}
with open("/home/mouren/Data/final_files_tokeep/other_species/control/dm6_control_neg_NoTF_NoTSS_TES.tsv") as file1:
    for line1 in file1: 
        exon = line1.strip().split("\t")[3]
        tr = (line1.strip().split("\t")[3]).split("_")[0]
        gene = dm_gene_dic[(line1.strip().split("\t")[3]).split("_")[0]]

        with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/dm6_gene_unprot_id.tsv") as file2:
            found = False
            for line2 in file2:   
                if tr == line2.strip().split("\t")[1]:
                    if line2.strip().split("\t")[3] != "NA":
                        dm_neg_id[exon] = line2.strip().split("\t")[3]
                        found = True
                    elif line2.strip().split("\t")[4] != "NA":
                        dm_neg_id[exon] = line2.strip().split("\t")[4]
                        found = True 
                    elif line2.strip().split("\t")[5] != "NA":
                        dm_neg_id[exon] = line2.strip().split("\t")[5]
                        found = True
                    elif line2.strip().split("\t")[2] != "NA":
                        dm_neg_id[exon] = line2.strip().split("\t")[2]
                        found = True                  
                    break
            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if gene == line2.strip().split("\t")[0]:
                        if line2.strip().split("\t")[3] != "NA":
                            dm_neg_id[exon] = line2.strip().split("\t")[3]
                            found = True
                        elif line2.strip().split("\t")[4] != "NA":
                            dm_neg_id[exon] = line2.strip().split("\t")[4]
                            found = True 
                        elif line2.strip().split("\t")[5] != "NA":
                            dm_neg_id[exon] = line2.strip().split("\t")[5]
                            found = True
                        elif line2.strip().split("\t")[2] != "NA":
                            dm_neg_id[exon] = line2.strip().split("\t")[2]
                            found = True                  
                        break
            if found == False:
                print(exon,tr,gene)
                dm_neg_id[exon] = "NA"

with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/dm6_ee_uniprotID", 'w') as file:
    for key, value in dm_ee_id.items():
        file.write(f'{key}\t{value}\n')
with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/dm6_neg_uniprotID", 'w') as file:
    for key, value in dm_neg_id.items():
        file.write(f'{key}\t{value}\n')
# Out:
# FBtr0273336_cds_7_0_chr2R_17106633_f FBtr0273336 FBgn0050456
# FBtr0091649_cds_0_0_chrX_21093985_f FBtr0091649 FBgn0064123
# FBtr0100609_cds_4_0_chrX_21108783_f FBtr0100609 FBgn0031159
# FBtr0100609_cds_5_0_chrX_21109723_f FBtr0100609 FBgn0031159
# FBtr0100609_cds_6_0_chrX_21110468_f FBtr0100609 FBgn0031159

# %%
## TAIR
# prioritize the uniprot/swissprot entry; then uniprot/trembl; then gene name 

tair_ee = {}
with open("/home/mouren/Data/final_files_tokeep/other_species/tair10_EE.bed") as file1:
    for line1 in file1: 
        exon = line1.strip().split("\t")[3]
        tr = (line1.strip().split("\t")[3]).split("_")[0]
        gene = ((line1.strip().split("\t")[3]).split("_")[0]).split(".")[0]

        with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/tair10_gene_unprot_id.tsv") as file2:
            found = False
            for line2 in file2:   
                if tr == line2.strip().split("\t")[1]:
                    if line2.strip().split("\t")[3] != "NA" :
                        tair_ee[exon] = line2.strip().split("\t")[3]
                        found = True
                    elif line2.strip().split("\t")[4] != "NA":
                        tair_ee[exon] = line2.strip().split("\t")[4]
                        found = True 
                    elif line2.strip().split("\t")[2] != "NA":
                        tair_ee[exon] = line2.strip().split("\t")[2]
                        found = True                  
                    break

            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if gene == line2.strip().split("\t")[0]:
                        if line2.strip().split("\t")[3] != "NA":
                            tair_ee[exon] = line2.strip().split("\t")[3]
                            found = True
                        elif line2.strip().split("\t")[4] != "NA":
                            tair_ee[exon] = line2.strip().split("\t")[4]
                            found = True 
                        elif line2.strip().split("\t")[2] != "NA":
                            tair_ee[exon] = line2.strip().split("\t")[2]
                            found = True                  
                        break
            if found == False:
                print(exon,tr,gene)
                tair_ee[exon] = "NA"

tair_neg = {}
with open("/home/mouren/Data/final_files_tokeep/other_species/control/tair10_control_neg_NoTF_NoTSS_TES.tsv") as file1:
    for line1 in file1: 
        exon = line1.strip().split("\t")[3]
        tr = (line1.strip().split("\t")[3]).split("_")[0]
        gene = ((line1.strip().split("\t")[3]).split("_")[0]).split(".")[0]

        with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/tair10_gene_unprot_id.tsv") as file2:
            found = False
            for line2 in file2:   
                if tr == line2.strip().split("\t")[1]:
                    if line2.strip().split("\t")[3] != "NA":
                        tair_neg[exon] = line2.strip().split("\t")[3]
                        found = True
                    elif line2.strip().split("\t")[4] != "NA":
                        tair_neg[exon] = line2.strip().split("\t")[4]
                        found = True 
                    elif line2.strip().split("\t")[2] != "NA":
                        tair_neg[exon] = line2.strip().split("\t")[2]
                        found = True                  
                    break

            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if gene == line2.strip().split("\t")[0]:
                        if line2.strip().split("\t")[3] != "NA":
                            tair_neg[exon] = line2.strip().split("\t")[3]
                            found = True
                        elif line2.strip().split("\t")[4] != "NA":
                            tair_neg[exon] = line2.strip().split("\t")[4]
                            found = True 
                        elif line2.strip().split("\t")[2] != "NA":
                            tair_neg[exon] = line2.strip().split("\t")[2]
                            found = True                  
                        break
            if found == False:
                print(exon,tr,gene)
                tair_neg[exon] = "NA"

with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/tair_ee_uniprotID", 'w') as file:
    for key, value in tair_ee.items():
        file.write(f'{key}\t{value}\n')
with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/tair_neg_uniprotID", 'w') as file:
    for key, value in tair_neg.items():
        file.write(f'{key}\t{value}\n')

# %%
### MM
mm_gene_dic1 = {}
mm_gene_dic2 = {}
with open("/mnt/project/exonhancer/ZENODO_REPO/EE_selection/other_species/data/gencode/mm39/raw/ensembl_geneID_transcriptID_mm39.txt") as file:
    for line in file:   
        mm_gene_dic1[line.strip().split("\t")[1]] = line.strip().split("\t")[0]
        mm_gene_dic2[line.strip().split("\t")[1].split(".")[0]] = line.strip().split("\t")[0]

mm_ee = {}
with open("/home/mouren/Data/final_files_tokeep/other_species/mm39_EE.bed") as file1:
    for line1 in file1: 
        exon = line1.strip().split("\t")[3]
        tr_v = (line1.strip().split("\t")[3]).split("_")[0]
        tr = ((line1.strip().split("\t")[3]).split("_")[0]).split(".")[0]
        try:
            gene = mm_gene_dic1[(line1.strip().split("\t")[3]).split("_")[0]]
        except KeyError:
            gene = mm_gene_dic2[((line1.strip().split("\t")[3]).split("_")[0]).split(".")[0]]
        
        
        with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/mm39_gene_unprot_id.tsv") as file2:
            found = False
            for line2 in file2:   
                if tr_v == line2.strip().split("\t")[2]:
                    if line2.strip().split("\t")[4] != "NA" :
                        mm_ee[exon] = line2.strip().split("\t")[4]
                        found = True
                    elif line2.strip().split("\t")[5] != "NA":
                        mm_ee[exon] = line2.strip().split("\t")[5]
                        found = True 
                    elif line2.strip().split("\t")[3] != "NA":
                        mm_ee[exon] = line2.strip().split("\t")[3]
                        found = True                  
                    break

            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if tr == line2.strip().split("\t")[1]:
                        if line2.strip().split("\t")[4] != "NA":
                            mm_ee[exon] = line2.strip().split("\t")[4]
                            found = True
                        elif line2.strip().split("\t")[5] != "NA":
                            mm_ee[exon] = line2.strip().split("\t")[5]
                            found = True 
                        elif line2.strip().split("\t")[3] != "NA":
                            mm_ee[exon] = line2.strip().split("\t")[3]
                            found = True                  
                        break
            
            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if gene == line2.strip().split("\t")[0]:
                        if line2.strip().split("\t")[4] != "NA":
                            mm_ee[exon] = line2.strip().split("\t")[4]
                            found = True
                        elif line2.strip().split("\t")[5] != "NA":
                            mm_ee[exon] = line2.strip().split("\t")[5]
                            found = True 
                        elif line2.strip().split("\t")[3] != "NA":
                            mm_ee[exon] = line2.strip().split("\t")[3]
                            found = True                  
                        break

            if found == False:
                print(exon,tr,gene)
                mm_ee[exon] = "NA"

## neg
mm_neg = {}
with open("/home/mouren/Data/final_files_tokeep/other_species/control/mm39_control_neg_NoTF_NoTSS_TES_prom.tsv") as file1:
    for line1 in file1: 
        exon = line1.strip().split("\t")[3]
        tr_v = (line1.strip().split("\t")[3]).split("_")[0]
        tr = ((line1.strip().split("\t")[3]).split("_")[0]).split(".")[0]
        try:
            gene = mm_gene_dic1[(line1.strip().split("\t")[3]).split("_")[0]]
        except KeyError:
            try:
                gene = mm_gene_dic2[((line1.strip().split("\t")[3]).split("_")[0]).split(".")[0]]
            except KeyError:
                gene = "NA"
        
        
        with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/mm39_gene_unprot_id.tsv") as file2:
            found = False
            for line2 in file2:   
                if tr_v == line2.strip().split("\t")[2]:
                    if line2.strip().split("\t")[4] != "NA" :
                        mm_neg[exon] = line2.strip().split("\t")[4]
                        found = True
                    elif line2.strip().split("\t")[5] != "NA":
                        mm_neg[exon] = line2.strip().split("\t")[5]
                        found = True 
                    elif line2.strip().split("\t")[3] != "NA":
                        mm_neg[exon] = line2.strip().split("\t")[3]
                        found = True                  
                    break

            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if tr == line2.strip().split("\t")[1]:
                        if line2.strip().split("\t")[4] != "NA":
                            mm_neg[exon] = line2.strip().split("\t")[4]
                            found = True
                        elif line2.strip().split("\t")[5] != "NA":
                            mm_neg[exon] = line2.strip().split("\t")[5]
                            found = True 
                        elif line2.strip().split("\t")[3] != "NA":
                            mm_neg[exon] = line2.strip().split("\t")[3]
                            found = True                  
                        break
            
            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if gene == line2.strip().split("\t")[0]:
                        if line2.strip().split("\t")[4] != "NA":
                            mm_neg[exon] = line2.strip().split("\t")[4]
                            found = True
                        elif line2.strip().split("\t")[5] != "NA":
                            mm_neg[exon] = line2.strip().split("\t")[5]
                            found = True 
                        elif line2.strip().split("\t")[3] != "NA":
                            mm_neg[exon] = line2.strip().split("\t")[3]
                            found = True                  
                        break

            if found == False:
                print(exon,tr,gene)
                mm_neg[exon] = "NA"

with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/mm_ee_uniprotID", 'w') as file:
    for key, value in mm_ee.items():
        file.write(f'{key}\t{value}\n')
with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/mm_neg_uniprotID", 'w') as file:
    for key, value in mm_neg.items():
        file.write(f'{key}\t{value}\n')
# Out:
# ENSMUST00000111493.8_cds_21_0_chr2_90266754_r ENSMUST00000111493 NA
# ENSMUST00000111493.8_cds_19_0_chr2_90270969_r ENSMUST00000111493 NA
# ENSMUST00000111493.8_cds_18_0_chr2_90274764_r ENSMUST00000111493 NA
# ENSMUST00000111493.8_cds_17_0_chr2_90276500_r ENSMUST00000111493 NA
# ENSMUST00000111493.8_cds_16_0_chr2_90276728_r ENSMUST00000111493 NA
# ENSMUST00000111493.8_cds_15_0_chr2_90278403_r ENSMUST00000111493 NA
# ENSMUST00000111493.8_cds_11_0_chr2_90282404_r ENSMUST00000111493 NA
# ENSMUST00000111493.8_cds_8_0_chr2_90285437_r ENSMUST00000111493 NA
# ENSMUST00000111493.8_cds_2_0_chr2_90298594_r ENSMUST00000111493 NA
# ENSMUST00000105634.8_cds_9_0_chr4_154973652_f ENSMUST00000105634 NA
# ENSMUST00000215525.2_cds_2_0_chr9_106404155_r ENSMUST00000215525 NA

# %%
## HSAP
hg_gene_dic1 = {}
hg_gene_dic2 = {}
with open("/home/mouren/Data/final_files_tokeep/notes/list_transript_gene_id_gencodeV41_all_proteincoding.tsv") as file:
    for line in file:   
        hg_gene_dic1[line.strip().split("\t")[0]] = (line.strip().split("\t")[1]).split(".")[0]
        hg_gene_dic2[line.strip().split("\t")[0].split(".")[0]] = (line.strip().split("\t")[1]).split(".")[0]

hg_ee = {}
with open("/home/mouren/Data/final_files_tokeep/other_species/hg38_EE.bed") as file1:
    for line1 in file1: 
        exon = line1.strip().split("\t")[3]
        tr_v = (line1.strip().split("\t")[3]).split("_")[0]
        tr = ((line1.strip().split("\t")[3]).split("_")[0]).split(".")[0]
        try:
            gene = hg_gene_dic1[(line1.strip().split("\t")[3]).split("_")[0]]
        except KeyError:
            try:
                gene = hg_gene_dic2[((line1.strip().split("\t")[3]).split("_")[0]).split(".")[0]]
            except KeyError:
                gene = "NA"
        
        
        with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/hg38_gene_unprot_id.tsv") as file2:
            found = False
            for line2 in file2:   
                if tr_v == line2.strip().split("\t")[2]:
                    if line2.strip().split("\t")[4] != "NA" :
                        hg_ee[exon] = line2.strip().split("\t")[4]
                        found = True
                    elif line2.strip().split("\t")[5] != "NA":
                        hg_ee[exon] = line2.strip().split("\t")[5]
                        found = True 
                    elif line2.strip().split("\t")[3] != "NA":
                        hg_ee[exon] = line2.strip().split("\t")[3]
                        found = True                  
                    break

            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if tr == line2.strip().split("\t")[1]:
                        if line2.strip().split("\t")[4] != "NA":
                            hg_ee[exon] = line2.strip().split("\t")[4]
                            found = True
                        elif line2.strip().split("\t")[5] != "NA":
                            hg_ee[exon] = line2.strip().split("\t")[5]
                            found = True 
                        elif line2.strip().split("\t")[3] != "NA":
                            hg_ee[exon] = line2.strip().split("\t")[3]
                            found = True                  
                        break
            
            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if gene == line2.strip().split("\t")[0]:
                        if line2.strip().split("\t")[4] != "NA":
                            hg_ee[exon] = line2.strip().split("\t")[4]
                            found = True
                        elif line2.strip().split("\t")[5] != "NA":
                            hg_ee[exon] = line2.strip().split("\t")[5]
                            found = True 
                        elif line2.strip().split("\t")[3] != "NA":
                            hg_ee[exon] = line2.strip().split("\t")[3]
                            found = True                  
                        break

            if found == False:
                print(exon,tr,gene)
                hg_ee[exon] = "NA"

## neg
hg_neg = {}
with open("/home/mouren/Data/final_files_tokeep/control/control_neg_NoTF_NoTSS_TES_prom.tsv") as file1:
    for line1 in file1: 
        exon = line1.strip().split("\t")[3]
        tr_v = (line1.strip().split("\t")[3]).split("_")[0]
        tr = ((line1.strip().split("\t")[3]).split("_")[0]).split(".")[0]
        try:
            gene = hg_gene_dic1[(line1.strip().split("\t")[3]).split("_")[0]]
        except KeyError:
            try:
                gene = hg_gene_dic2[((line1.strip().split("\t")[3]).split("_")[0]).split(".")[0]]
            except KeyError:
                gene = "NA"
        
        
        with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/hg38_gene_unprot_id.tsv") as file2:
            found = False
            for line2 in file2:   
                if tr_v == line2.strip().split("\t")[2]:
                    if line2.strip().split("\t")[4] != "NA" :
                        hg_neg[exon] = line2.strip().split("\t")[4]
                        found = True
                    elif line2.strip().split("\t")[5] != "NA":
                        hg_neg[exon] = line2.strip().split("\t")[5]
                        found = True 
                    elif line2.strip().split("\t")[3] != "NA":
                        hg_neg[exon] = line2.strip().split("\t")[3]
                        found = True                  
                    break

            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if tr == line2.strip().split("\t")[1]:
                        if line2.strip().split("\t")[4] != "NA":
                            hg_neg[exon] = line2.strip().split("\t")[4]
                            found = True
                        elif line2.strip().split("\t")[5] != "NA":
                            hg_neg[exon] = line2.strip().split("\t")[5]
                            found = True 
                        elif line2.strip().split("\t")[3] != "NA":
                            hg_neg[exon] = line2.strip().split("\t")[3]
                            found = True                  
                        break
            
            if found == False:
                file2.seek(0)
                for line2 in file2:   
                    if gene == line2.strip().split("\t")[0]:
                        if line2.strip().split("\t")[4] != "NA":
                            hg_neg[exon] = line2.strip().split("\t")[4]
                            found = True
                        elif line2.strip().split("\t")[5] != "NA":
                            hg_neg[exon] = line2.strip().split("\t")[5]
                            found = True 
                        elif line2.strip().split("\t")[3] != "NA":
                            hg_neg[exon] = line2.strip().split("\t")[3]
                            found = True                  
                        break

            if found == False:
                print(exon,tr,gene)
                hg_neg[exon] = "NA"

with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/hg_ee_uniprotID", 'w') as file:
    for key, value in hg_ee.items():
        file.write(f'{key}\t{value}\n')
with open("/home/mouren/Data/final_files_tokeep/notes/gene_names/hg_neg_uniprotID", 'w') as file:
    for key, value in hg_neg.items():
        file.write(f'{key}\t{value}\n')

# %%
#manual correction for entry with no results

# %%
def calculate_gc_content(dna_sequence):
    dna_sequence = dna_sequence.upper()

    g_count = dna_sequence.count('G')
    c_count = dna_sequence.count('C')

    total_length = len(dna_sequence)

    if total_length == 0:
        return 0.0
    gc_content_percentage = ((g_count + c_count) / total_length) * 100

    return gc_content_percentage

ee_h = {}
with open("/home/mouren/Data/final_files_tokeep/sequences_species/hsap/hg38_{ee}_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_m[line.strip().split("\t")[0]] = gc_content

with open("/home/mouren/Data/final_files_tokeep/notes/gc_perc/gc_perc_ee_dic_hg38.tsv", 'w') as f:
    for key, value in ee_h.items():
        f.write(f"{key}\t{value}\n")

ee_m = {}
with open("/home/mouren/Data/final_files_tokeep/sequences_species/mmus/mm39_{ee}_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_m[line.strip().split("\t")[0]] = gc_content

with open("/home/mouren/Data/final_files_tokeep/notes/gc_perc/gc_perc_ee_dic_mm.tsv", 'w') as f:
    for key, value in ee_m.items():
        f.write(f"{key}\t{value}\n")

ee_d = {}
with open("/home/mouren/Data/final_files_tokeep/sequences_species/dmel/dm6_{ee}_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_d[line.strip().split("\t")[0]] = gc_content

with open("/home/mouren/Data/final_files_tokeep/notes/gc_perc/gc_perc_ee_dic_dm.tsv", 'w') as f:
    for key, value in ee_d.items():
        f.write(f"{key}\t{value}\n")

ee_t = {}
with open("/home/mouren/Data/final_files_tokeep/sequences_species/thal/tair10_{ee}_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_t[line.strip().split("\t")[0]] = gc_content

with open("/home/mouren/Data/final_files_tokeep/notes/gc_perc/gc_perc_ee_dic_tair.tsv", 'w') as f:
    for key, value in ee_t.items():
        f.write(f"{key}\t{value}\n")

# %%
def calculate_gc_content(dna_sequence):
    dna_sequence = dna_sequence.upper()

    g_count = dna_sequence.count('G')
    c_count = dna_sequence.count('C')

    total_length = len(dna_sequence)

    if total_length == 0:
        return 0.0
    gc_content_percentage = ((g_count + c_count) / total_length) * 100

    return gc_content_percentage

ee_h = {}
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/hsap/hg38_neg_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_h[line.strip().split("\t")[0]] = gc_content

with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/gc_perc/gc_perc_neg_dic_hg.tsv", 'w') as f:
    for key, value in ee_h.items():
        f.write(f"{key}\t{value}\n")

ee_m = {}
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/mmus/mm39_neg_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_m[line.strip().split("\t")[0]] = gc_content

with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/gc_perc/gc_perc_neg_dic_mm.tsv", 'w') as f:
    for key, value in ee_m.items():
        f.write(f"{key}\t{value}\n")

ee_d = {}
with open("//mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/dmel/dm6_neg_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_d[line.strip().split("\t")[0]] = gc_content

with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/gc_perc/gc_perc_neg_dic_dm.tsv", 'w') as f:
    for key, value in ee_d.items():
        f.write(f"{key}\t{value}\n")

ee_t = {}
with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/sequences_species/thal/tair10_neg_dna_seqs.tsv") as file:
    for line in file:  
        dna_sequence = line.strip().split("\t")[1]
        gc_content = calculate_gc_content(dna_sequence)
        ee_t[line.strip().split("\t")[0]] = gc_content

with open("/mnt/project/exonhancer/ZENODO_REPO/Conservation_and_structure/structural_properties/gc_perc/gc_perc_neg_dic_tair.tsv", 'w') as f:
    for key, value in ee_t.items():
        f.write(f"{key}\t{value}\n")

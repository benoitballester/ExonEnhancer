# %%
### Packages
import matplotlib 
matplotlib.rcParams['pdf.fonttype'] = 42
from scipy.stats import fisher_exact
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

### EE data
#DNAse and ATAC overlap values were obtained from the EE_summary files 

### Ctrl- data
##HG
dic_h={}
with open("/home/mouren/Data/final_files_tokeep/dnase_atac/venn_plot/control/neg_atac_atlas") as file:
    for line in file:       
        if int(line.strip().split()[4]) != 0:
            if line.strip().split()[3] not in dic_h:
                dic_h[line.strip().split()[3]] = 1
            else:
                dic_h[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/dnase_atac/venn_plot/control/neg_dnase_atlas") as file:
    for line in file:       
        if int(line.strip().split()[4]) != 0:
            if line.strip().split()[3] not in dic_h:
                dic_h[line.strip().split()[3]] = 1
            else:
                dic_h[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/dnase_atac/venn_plot/control/neg_dnase_encode") as file:
    for line in file:       
        if int(line.strip().split()[4]) != 0:
            if line.strip().split()[3] not in dic_h:
                dic_h[line.strip().split()[3]] = 1
            else:
                dic_h[line.strip().split()[3]] += 1
##MM
dic_mm={}
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/mm_neg_atac") as file:
    for line in file:   
        if line.strip().split()[3] not in dic_mm:
            dic_mm[line.strip().split()[3]] = 1
        else:
            dic_mm[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/mm_neg_dnase") as file:
    for line in file:   
        if line.strip().split()[3] not in dic_mm:
            dic_mm[line.strip().split()[3]] = 1
        else:
            dic_mm[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/mm_neg_dnase_encode") as file:
    for line in file:   
        if line.strip().split()[3] not in dic_mm:
            dic_mm[line.strip().split()[3]] = 1
        else:
            dic_mm[line.strip().split()[3]] += 1
##DM
dic_dm={}
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/dm_neg_atac") as file:
    for line in file:           
        if line.strip().split()[3] not in dic_dm:
            dic_dm[line.strip().split()[3]] = 1
        else:
            dic_dm[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/dm_neg_dnase") as file:
    for line in file:           
        if line.strip().split()[3] not in dic_dm:
            dic_dm[line.strip().split()[3]] = 1
        else:
            dic_dm[line.strip().split()[3]] += 1
##TAIR
dic_t={}
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/tair_neg_atac") as file:
    for line in file:           
        if line.strip().split()[3] not in dic_t:
            dic_t[line.strip().split()[3]] = 1
        else:
            dic_t[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/tair_neg_dnase") as file:
    for line in file:           
        if line.strip().split()[3] not in dic_t:
            dic_t[line.strip().split()[3]] = 1
        else:
            dic_t[line.strip().split()[3]] += 1

### Ctrl- fisher exact test with EE
#hsap
hsap_neg = np.array([[11015, len(dic_h.keys())],
                  [13481-11015, 13253-len(dic_h.keys())]])

print(fisher_exact(hsap_neg,alternative="greater")) 
print("% neg hsap", (len(dic_h.keys())*100)/13253)

#mm
mm_neg = np.array([[8159, len(dic_mm.keys())],
                  [12244-8159, 18457-len(dic_mm.keys())]])

print(fisher_exact(mm_neg,alternative="greater")) 
print("% neg mm", (len(dic_mm.keys())*100)/18457)

#dmel
dmel_neg = np.array([[7425, len(dic_dm.keys())],
                  [13688-7425, 903-len(dic_dm.keys())]])

print(fisher_exact(dmel_neg,alternative="greater")) 
print("% neg dm", (len(dic_dm.keys())*100)/903)

#tair
t_neg = np.array([[6002, len(dic_t.keys())],
                  [7138-6002, 7862-len(dic_t.keys())]])

print(fisher_exact(t_neg,alternative="greater")) 
print("% neg tair", (len(dic_t.keys())*100)/7862)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 39
#      37 ##MM
#      38 dic_mm={}
# ---> 39 with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/mm_neg_atac") as file:
#      40     for line in file:
#      41         if line.strip().split()[3] not in dic_mm:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/mm_neg_atac'

# %%
### CTRL POS
##HG
dic_h={}
with open("/home/mouren/Data/final_files_tokeep/dnase_atac/venn_plot/control/pos_atac_atlas") as file:
    for line in file:       
        if int(line.strip().split()[4]) != 0:
            if line.strip().split()[3] not in dic_h:
                dic_h[line.strip().split()[3]] = 1
            else:
                dic_h[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/dnase_atac/venn_plot/control/pos_dnase_atlas") as file:
    for line in file:       
        if int(line.strip().split()[4]) != 0:
            if line.strip().split()[3] not in dic_h:
                dic_h[line.strip().split()[3]] = 1
            else:
                dic_h[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/dnase_atac/venn_plot/control/pos_dnase_encode") as file:
    for line in file:       
        if int(line.strip().split()[4]) != 0:
            if line.strip().split()[3] not in dic_h:
                dic_h[line.strip().split()[3]] = 1
            else:
                dic_h[line.strip().split()[3]] += 1
##MM
dic_mm={}
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/mm_pos_atac") as file:
    for line in file:   
        if line.strip().split()[3] not in dic_mm:
            dic_mm[line.strip().split()[3]] = 1
        else:
            dic_mm[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/mm_pos_dnase") as file:
    for line in file:   
        if line.strip().split()[3] not in dic_mm:
            dic_mm[line.strip().split()[3]] = 1
        else:
            dic_mm[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/mm_pos_dnase_encode") as file:
    for line in file:   
        if line.strip().split()[3] not in dic_mm:
            dic_mm[line.strip().split()[3]] = 1
        else:
            dic_mm[line.strip().split()[3]] += 1
##DM
dic_dm={}
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/dm_pos_atac") as file:
    for line in file:           
        if line.strip().split()[3] not in dic_dm:
            dic_dm[line.strip().split()[3]] = 1
        else:
            dic_dm[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/dm_pos_dnase") as file:
    for line in file:           
        if line.strip().split()[3] not in dic_dm:
            dic_dm[line.strip().split()[3]] = 1
        else:
            dic_dm[line.strip().split()[3]] += 1
##TAIR
dic_t={}
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/tair_pos_atac") as file:
    for line in file:           
        if line.strip().split()[3] not in dic_t:
            dic_t[line.strip().split()[3]] = 1
        else:
            dic_t[line.strip().split()[3]] += 1
with open("/home/mouren/Data/final_files_tokeep/other_species/dnase_atac_ovlp_result/tair_pos_dnase") as file:
    for line in file:           
        if line.strip().split()[3] not in dic_t:
            dic_t[line.strip().split()[3]] = 1
        else:
            dic_t[line.strip().split()[3]] += 1

### Ctrl+ fisher exact test with EE
#hsap
hsap_pos = np.array([[11015, len(dic_h.keys())],
                  [13481-11015, 404325-len(dic_h.keys())]])
print(fisher_exact(hsap_pos,alternative="greater")) 
print ("% pos hsap", (len(dic_h.keys())*100)/404325)

#mm
mm_pos = np.array([[8159, len(dic_mm.keys())],
                  [12244-8159, 149241-len(dic_mm.keys())]])
print(fisher_exact(mm_pos,alternative="greater")) 
print ("% pos mm", (len(dic_mm.keys())*100)/149241)

#dmel
dmel_pos = np.array([[7425, len(dic_dm.keys())],
                  [13688-7425, 133253-len(dic_dm.keys())]])
print(fisher_exact(dmel_pos,alternative="greater")) 
print ("% pos dm", (len(dic_dm.keys())*100)/133253)

#tair
t_pos = np.array([[6002, len(dic_t.keys())],
                  [7138-6002, 9025-len(dic_t.keys())]])
print(fisher_exact(t_pos,alternative="greater")) 
print ("% pos tair", (len(dic_t.keys())*100)/9025)
# Out:
# SignificanceResult(statistic=0.0052869166637391244, pvalue=1.0)
# % pos hsap 99.88177827242936
# SignificanceResult(statistic=0.0004952974933451008, pvalue=1.0)
# % pos mm 99.9752078852326
# SignificanceResult(statistic=0.2864334665470135, pvalue=1.0)
# % pos dm 80.54077581743
# SignificanceResult(statistic=0.09414516874564177, pvalue=1.0)
# % pos tair 98.24930747922437

# %%
### PLOT

plt.figure(figsize=(5, 5))

dataf = [
{"Dataset":"H.sap","Exons":"cEEs","% Overlap":95.55},
{"Dataset":"H.sap","Exons":"Ctrl-","% Overlap":33.24}, 
{"Dataset":"H.sap","Exons":"Ctrl+","% Overlap":99.88177827242936},

{"Dataset":"M.mus","Exons":"cEEs","% Overlap":86.37},  
{"Dataset":"M.mus","Exons":"Ctrl-","% Overlap":21.86}, 
{"Dataset":"M.mus","Exons":"Ctrl+","% Overlap":99.9752078852326},

{"Dataset":"D.mel","Exons":"cEEs","% Overlap":54.24},  
{"Dataset":"D.mel","Exons":"Ctrl-","% Overlap":15.614617940199336}, 
{"Dataset":"D.mel","Exons":"Ctrl+","% Overlap":80.54077581743},

{"Dataset":"A.tha","Exons":"cEEs","% Overlap":84.09},  
{"Dataset":"A.tha","Exons":"Ctrl-","% Overlap":43.474942762655814}, 
{"Dataset":"A.tha","Exons":"Ctrl+","% Overlap":98.24930747922437},
]

df = pd.DataFrame(dataf)

clrs = ['red' if (y == 95.55) else 'silver' if (y == 33.24) else "mediumorchid" for y in df["% Overlap"]]

ax = sns.barplot(data=df, x="Dataset", y="% Overlap", hue="Exons",palette=clrs)

from statannot import add_stat_annotation
box_pairs = [
    (("H.sap", "cEEs"), ("H.sap", "Ctrl-")),
    (("H.sap", "cEEs"), ("H.sap", "Ctrl+")),
    (("M.mus", "cEEs"), ("M.mus", "Ctrl-")),
    (("M.mus", "cEEs"), ("M.mus", "Ctrl+")),
    (("D.mel", "cEEs"), ("D.mel", "Ctrl-")),
    (("D.mel", "cEEs"), ("D.mel", "Ctrl+")),
    (("A.tha", "cEEs"), ("A.tha", "Ctrl-")),
    (("A.tha", "cEEs"), ("A.tha", "Ctrl+")),
]

custom_pvalues = [0,1,0,1,4.250843258554177e-121,1,0,1] #from the fisher test

add_stat_annotation(ax, data=df, x="Dataset", y="% Overlap", hue="Exons", order=["H.sap","M.mus","D.mel","A.tha"],
                    box_pairs=box_pairs,
                    pvalues=custom_pvalues, perform_stat_test=False, test=None, text_format='simple', loc='inside', verbose=1)

sns.despine(top=True, right=True, left=False, bottom=False)
plt.legend(bbox_to_anchor=(1.01, 1), frameon=False)
plt.yticks(fontsize=5)
plt.xticks(fontsize=8)
plt.xlabel("", fontsize=8)
plt.ylabel("% Overlap", fontsize=8)

plt.ylim(0,120)
ticks = ax.get_yticks()
labels = ax.get_yticklabels()
ax.set_yticks(ticks[:-1])
ax.set_yticklabels(labels[:-1])

#plt.tight_layout()

plt.savefig("/home/mouren/Images/supplementary_figures/supp_fig2/dnase_atac_overlap_all_species.pdf", format="pdf", bbox_inches="tight", dpi=450)
plt.savefig("/home/mouren/Images/supplementary_figures/supp_fig2/dnase_atac_overlap_all_species.png", format="png", bbox_inches="tight", dpi=450)

plt.show()
# Out:
# D.mel_cEEs v.s. D.mel_Ctrl-: Custom statistical test, P_val:4.251e-121
# A.tha_cEEs v.s. A.tha_Ctrl-: Custom statistical test, P_val:0.000e+00
# H.sap_cEEs v.s. H.sap_Ctrl-: Custom statistical test, P_val:0.000e+00
# M.mus_cEEs v.s. M.mus_Ctrl-: Custom statistical test, P_val:0.000e+00
# D.mel_cEEs v.s. D.mel_Ctrl+: Custom statistical test, P_val:1.000e+00
# A.tha_cEEs v.s. A.tha_Ctrl+: Custom statistical test, P_val:1.000e+00
# M.mus_cEEs v.s. M.mus_Ctrl+: Custom statistical test, P_val:1.000e+00
# H.sap_cEEs v.s. H.sap_Ctrl+: Custom statistical test, P_val:1.000e+00

# %%
import matplotlib 
import matplotlib.pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42

import numpy as np

categories = ['H.sapiens', 'M.musculus', 'D.melanogaster', 'A.thaliana']
cano = [13481,12244,13688,7138] 

fig, ax = plt.subplots(figsize=(7,5))

ax.bar(categories, cano, label='Canonical',color=["red","gray","orange","green"])

ax.set_ylabel('Nb of exons')

plt.savefig("/home/mouren/Images/tls1/other_species/exons_Nocategories_repartition_all_species.pdf", format="pdf", bbox_inches="tight")

plt.show()
